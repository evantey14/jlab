# %%
import pandas as pd
import numpy as np
import math
import scipy.optimize as opt
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# define models to fit to

# E/B = B / (mc^2/re)
def classical(x, a):
    return x/a

# E/B = B / sqrt((mc^2/re)^2 + B^2)
def relativistic(x, a):
    return x/(a**2+x**2)**.5

def gaussian(x, a, m, s):
    return a * np.exp(-(x-m)**2/(2*s**2))

# %%
def fit_model(x ,y, ey, p0, model):
    # fit data to model
    popt, pcov = opt.curve_fit(f=model, xdata=x, ydata=y, p0=p0, sigma=ey, absolute_sigma=True)
    
    # calculate error on parameters
    perr = np.sqrt(np.diag(pcov))
    
    # calculate chi sq value
    r = np.array([yi - model(xi, *popt) for (xi, yi) in zip(x, y)])
    chisq = sum((r / ey)**2)
    
    return popt, perr, chisq

# %%
def init_plot():
    plt.figure(figsize=(8.6,7))
    matplotlib.rcParams.update({'font.size': 16})
    
def plot_data(x, y, ey):
    plt.errorbar(x, y, yerr=ey, fmt='o')
    
def plot_model(x, model, p):
    plt.plot(x, [model(xi, *p) for xi in x] , color='r', linewidth=2.5, label='$ae^{-(x-\mu)^2/2\sigma^2}$')
    
# plot helper function. meant to be changed
def plot(x, y, ey, model, p):
    init_plot()
    
    plot_data(x, y, ey)
    plot_model(x, model, p)
    
    plt.xlabel('')
    plt.ylabel('')
    #plt.text(2850, 40, '$a=42.28\pm4.21$\n$\mu=3460.70\pm8.81$\n$\sigma=95.97\pm4.71$\n$\chi^2=81.30$\n$p<.0001$\n$counts=220$')
    plt.legend()
    
    plt.grid(True)
    
    # plt.savefig('as3.png')
    plt.show()
    
def multiplot(x, y, ey, model1, p1, model2, p2):
    init_plot()
    
    plot_data(x, y, ey)
    plot_model(x, model1, p1)
    plot_model(x, model2, p2)
    
    plt.show()

# %%
x, y, ey = {}, {}, {}
raw_data = pd.read_csv('reldyn.csv').set_index('type')
bs = list(raw_data)
print(bs)
for b in bs:
    x[b] = [float(i) for i in raw_data[b]['x'].split(', ')]
    y[b] = [float(i) for i in raw_data[b]['y'].split(', ')]
    ey[b] = [float(i) for i in raw_data[b]['ey'].split(', ')]
# Out:
# ['40', '50', '60', '70', '80', '90', '100']

# %%
popt, perr, chisq = {}, {}, {}
for b in bs:
    print("B =", b) 
    
    # generate p0 according to a silly approximation
    p0 = (10, .025*int(b)+.4, .3)

    popt[b], perr[b], chisq[b] = fit_model(x=x[b], y=y[b], ey=ey[b], p0=p0, model=gaussian)
    
    print(popt[b], perr[b], chisq[b])
    #plot(x[b], y[b], ey[b], gaussian, popt[b])
    print('------------------------------')
# Out:
# B = 40
# [ 2.8223831   0.81871834  0.4491367 ] [ 0.09161405  0.03575969  0.07416238] 125.511021086
# ------------------------------
# B = 50
# [ 0.23928808  1.37780334  0.26711269] [ 0.02448997  0.02655379  0.03046529] 14.3322894277
# ------------------------------
# B = 60
# [ 0.26065777  1.8507577   0.14370323] [ 0.03129821  0.01615998  0.01507018] 13.4781979158
# ------------------------------
# B = 70
# [ 0.3314698   2.35451857  0.26879869] [ 0.0288762   0.02079297  0.02294439] 18.8360797981
# ------------------------------
# B = 80
# [ 0.51177824  2.6322359   0.233391  ] [ 0.0384549   0.01672861  0.01930723] 5.94419656699
# ------------------------------
# B = 90
# [ 0.78367346  3.17221718  0.24440867] [ 0.04773445  0.01476693  0.01802811] 14.8814231936
# ------------------------------
# B = 100
# [ 0.95186043  3.58474614  0.43029529] [ 0.04228415  0.0532606   0.04978061] 40.1067656775
# ------------------------------

# %%
# make list of B (p), E/B (v), and error in E/B (ev) based on fitted gaussians
p = [int(i) for i in list(popt.keys())]

# scale B by the factor we found through calibration
adj_p = [0.9452322125*i for i in p]

# [E]/B = [voltage(kV) * conversion (statv/kV) / separation (cm)] / B (G)
v = [popt[str(p[i])][1]*3.3356409519815/0.18/adj_p[i] for i in range(len(p))] # need to take into account the error...
ev = [i[2] for i in list(popt.values())]
t
print(adj_p, '\n', v, '\n', ev)

cls_p, cls_perr, cls_chisq = fit_model(adj_p, v, ev, (83.97157), classical)
multiplot(adj_p, v, ev, classical, cls_p, classical, [83.97157])
print(cls_p, cls_perr)

rel_p, rel_perr, rel_chisq = fit_model(adj_p, v, ev, (83.97157), relativistic)
multiplot(adj_p, v, ev, relativistic, rel_p, relativistic, [83.97157])
print(rel_p, rel_perr)

multiplot(adj_p, v, ev, classical, [83.97157], relativistic, [83.97157])
# Out:
# [37.8092885, 47.261610625, 56.71393275, 66.166254875, 75.618577, 85.070899125, 94.52322125]
#  [0.40127072268912067, 0.54023183686819598, 0.60472964669988571, 0.65942745771980704, 0.64505651728288849, 0.69100843717242266, 0.702783169667894]
#  [0.44913670215078266, 0.26711268720773212, 0.14370322964910567, 0.26879868645885607, 0.23339099676451008, 0.24440866966969338, 0.43029528586464788]
# [ 107.19510613] [ 15.79671993]
# [ 79.35615807] [ 19.45600625]
