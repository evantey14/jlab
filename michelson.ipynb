# %%
import pandas as pd
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
v = [0.7313432836,
0.7185185185,
0.7121212121,
0.7185185185,
0.7185185185,
0.6692913386,
0.5909090909,
0.5671641791,
0.5789473684,
0.5757575758,
0.5909090909,
0.5789473684,
0.5939849624]

# %%
#from scipy.stats import norm
plt.figure(figsize=(8.6,7))

matplotlib.rcParams.update({'font.size': 16})

binsize = 125
raw_counts = plt.hist(v, 
                      #bins=np.arange(min(cubedf['v']), max(cubedf['v']) + binsize, binsize), 
                      alpha=.5,
                      edgecolor='black',
                      linewidth=2.0)
                      #label='raw counts')

#x = np.linspace(min(cubedf['v']), max(cubedf['v']), 1000)
#mean = stats['mean'].loc['v']
#std = stats['mean'].loc['ev']
#gaussian = plt.plot(x, binsize*len(cubedf)*norm.pdf(x, mean, std), color='r', linewidth=2.5, label='Gaussian model')

plt.xlabel('Visibility')
plt.ylabel('Counts')
#plt.text(2900, 40, '$\mu=3400$\n$\sigma=200$\n$counts=220$')
#plt.legend()
plt.grid(True)
plt.savefig('michelson/visibility.png')
plt.show()

# %%
c=[34.09482759,
39.55,
37.31132075,
41.19791667,
37.31132075,
38.02884615,
36.62037037,
38.7745098,
40.35714286,
38.7745098,
39.55,
36.62037037,
37.31132075]

# %%
plt.figure(figsize=(8.6,7))

matplotlib.rcParams.update({'font.size': 16})

binsize = 125
raw_counts = plt.hist(c, 
                      
                      alpha=.5,
                      edgecolor='black',
                      linewidth=2.0)
                      
plt.xlabel('Calibration Factor')
plt.ylabel('Counts')

plt.grid(True)
plt.savefig('michelson/calibrationfactor.png')
plt.show()
